# %%
# First get bucket path
res = !wb resource resolve --id bucket_for_storage_across_apps
bucket = res[0]
print(f"Bucket: {bucket}")

# %%
# Copy the VCF and its index
local_vcf = "bag3_full_region.vcf.bgz"
# !gsutil cp {bucket}/bag3_full_region.vcf.bgz {local_vcf}
print("Done.")

# %%
# !conda install -y -c bioconda htslib

# %%
# !tabix -p vcf bag3_full_region.vcf.bgz

# %%
# !pip install pysam
#necessary for actually analyzing the VCF
