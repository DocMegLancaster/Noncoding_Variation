# %% [markdown]
# # Predict regulatory regions around DSP (AlphaGenome)
#
# This notebook runs AlphaGenome interval predictions for left-ventricle heart tissue around *DSP*, isolates high-signal candidate regulatory regions from chromatin and transcription modalities, exports per-modality / per-histone peaks as BED, collapses completely nested intervals into parent/member tables, and overlays the collapsed regions (colored by modality or histone mark) on multi-track plots.
#
# **Run with the py311 kernel.**

# %% [markdown]
# # Setup
#
# Load libraries, shared paths and constants, the AlphaGenome model, and GENCODE transcript extractors used throughout.

# %% [markdown]
# ## Imports
#
# Import AlphaGenome model/genome/transcript helpers, plotting utilities, and pandas/numpy.
#
# **Make sure to run using AG kernel**

# %%
from __future__ import annotations

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

import matplotlib.patches as mpatches

from alphagenome.data import gene_annotation, genome, transcript
from alphagenome.visualization import plot_components
from alphagenome.models import dna_client
from alphagenome.models import variant_scorers  
from alphagenome_research.model import dna_model

TARGET_GENE = "DSP"

BASE_PATH = '/fs/scratch/PAS3488/Morales/AG_Project/'
AG_DATA_PATH = '/fs/scratch/PAS3488/Morales/AG_Project/AG_Project/alphagenome_data/'

# --- Reference files ---
HG38_FASTA_PATH    = "/fs/scratch/PAS3488/Morales/AG_Project/AG_Project/hg38.fa"
HG38_GTF_PATH      = "/fs/scratch/PAS3488/Morales/AG_Project/AG_Project/alphagenome_data/gencode.v46.annotation.gtf.gz.feather"
HG38_SPLICE_START_PATH = "/fs/scratch/PAS3488/Morales/AG_Project/AG_Project/alphagenome_data/gencode.v46.splice_sites_starts.feather"
HG38_SPLICE_END_PATH   = "/fs/scratch/PAS3488/Morales/AG_Project/AG_Project/alphagenome_data/gencode.v46.splice_sites_ends.feather"

# calibration scores link
# https://storage.googleapis.com/alphagenome/data/hg38/calibration_scores.pb
CALIBRATION_PATH = f'{AG_DATA_PATH}calibration_scores.pb'

HEART_UB = 'UBERON:0000948' # heart
LV_UB = 'UBERON:0002084' # LV

# Full Context Window for AG
SEQUENCE_LENGTH = dna_client.SEQUENCE_LENGTH_1MB  # 1_048_576 

output_modalities = ['atac',	
    'cage',	
    'chip_histone',	
    'chip_tf',	
    'contact_maps',	
    'dnase',	
    'procap',	
    'rna_seq',	
    'splice_junctions',	
    'splice_site_usage',	
    'splice_sites']

requested_outputs = {dna_client.OutputType.ATAC,
        dna_client.OutputType.CAGE,
        dna_client.OutputType.DNASE,
        dna_client.OutputType.PROCAP,
        dna_client.OutputType.RNA_SEQ,
        dna_client.OutputType.SPLICE_SITES,
        dna_client.OutputType.SPLICE_SITE_USAGE,
        dna_client.OutputType.SPLICE_JUNCTIONS,
        dna_client.OutputType.CONTACT_MAPS,
        dna_client.OutputType.CHIP_HISTONE,
        dna_client.OutputType.CHIP_TF}


MODALITY_COLORS = {
    "dnase": "#e377c2",          # pink
    "atac": "#17becf",           # cyan
    "chip_histone": "#d62728",   # red
    "chip_tf": "#9467bd",        # purple
    "rna_seq": "#2ca02c",        # green
    "cage": "#8c564b",           # brown
    "splice": "#ff7f0e",         # orange
    "contact_maps": "#1f77b4",   # blue
}

HISTONE_MARKS = ["H3K4me3", "H3K4me1", "H3K9ac", "H3K27ac", "H3K36me3", "H3K9me3", "H3K27me3"]

HISTONE_COLORS = {
    "H3K4me3": "#e41a1c",   # red — active promoter
    "H3K4me1": "#ff7f00",   # orange — enhancer
    "H3K9ac": "#984ea3",    # purple — active chromatin
    "H3K27ac": "#4daf4a",   # green — active enhancer/promoter
    "H3K36me3": "#377eb8",  # blue — gene body / elongation
    "H3K9me3": "#a65628",   # brown — heterochromatin / repression
    "H3K27me3": "#025669",

}

# ENCODE-style cCRE class colors (RGB matches ENCODE portal conventions)
CCRE_COLORS = {
    "Promoter": "#FF0000",              # red
    "Proximal enhancer": "#FFA700",     # orange
    "Distal enhancer": "#FFCD00",       # yellow/gold
    "CA": "#06DA93",                    # teal/green
    "CA-CTCF": "#00B0F0",               # cyan/blue
    "CA-H3K4me3": "#FFAAAA",            # light pink
    "CA-TF": "#D876EC",                 # purple (TF with accessibility)
    "TF": "#D876EC",                    # purple
}

# %% [markdown]
# ## Load AlphaGenome model
#
# Create the HuggingFace `all_folds` model with local hg38 FASTA, GTF feather, and splice-site feather paths under `OrganismSettings`.

# %%
model = dna_model.create_from_huggingface( 
    'all_folds', 
    organism_settings={ 
        dna_model.Organism.HOMO_SAPIENS: dna_model.OrganismSettings( 
            fasta_path=HG38_FASTA_PATH, 
            gtf_feather_path=HG38_GTF_PATH, 
            splice_site_starts_feather_path=HG38_SPLICE_START_PATH, 
            splice_site_ends_feather_path=HG38_SPLICE_END_PATH, 
            calibration_path=CALIBRATION_PATH,
        ), dna_model.Organism.MUS_MUSCULUS: dna_model.OrganismSettings() } )

print("model initialized")
# Out:
# Fetching 12 files: 100%|██████████| 12/12 [00:00<00:00, 1760.46it/s]
# /fs/scratch/PAS3488/Morales/conda/envs/py311/lib/python3.11/site-packages/pandas/io/feather_format.py:123: FutureWarning: pyarrow.feather.read_feather is deprecated as of 24.0.0. Use pyarrow.ipc.open_file() / RecordBatchFileReader instead. Feather V2 is the Arrow IPC file format.
#   return feather.read_feather(
# /fs/scratch/PAS3488/Morales/conda/envs/py311/lib/python3.11/site-packages/pandas/io/feather_format.py:123: FutureWarning: pyarrow.feather.read_feather is deprecated as of 24.0.0. Use pyarrow.ipc.open_file() / RecordBatchFileReader instead. Feather V2 is the Arrow IPC file format.
#   return feather.read_feather(
# /fs/scratch/PAS3488/Morales/conda/envs/py311/lib/python3.11/site-packages/pandas/io/feather_format.py:123: FutureWarning: pyarrow.feather.read_feather is deprecated as of 24.0.0. Use pyarrow.ipc.open_file() / RecordBatchFileReader instead. Feather V2 is the Arrow IPC file format.
#   return feather.read_feather(
# model initialized

# %% [markdown]
# ## Gene and transcript annotations
#
# Load the GENCODE GTF feather, filter to protein-coding transcripts with support level 1, and build both a full `TranscriptExtractor` and a longest-transcript extractor for interval plots.

# %%
# Load gene annotations (from GENCODE).
gtf = pd.read_feather(HG38_GTF_PATH)

# Filter to protein-coding genes and highly supported transcripts.
gtf_transcript = gene_annotation.filter_transcript_support_level(
    gene_annotation.filter_protein_coding(gtf), ['1']
)

# Extractor for identifying transcripts in a region.
transcript_extractor = transcript.TranscriptExtractor(gtf_transcript)

# Also define an extractor that fetches only the longest transcript per gene.
gtf_longest_transcript = gene_annotation.filter_to_longest_transcript(
    gtf_transcript
)
longest_transcript_extractor = transcript.TranscriptExtractor(
    gtf_longest_transcript
)

GENE_INTERVAL = gene_annotation.get_gene_interval(gtf, gene_symbol=TARGET_GENE)
GENE_INTERVAL
GENE_START = GENE_INTERVAL.start
GENE_END = GENE_INTERVAL.end
# Out:
# /fs/scratch/PAS3488/Morales/conda/envs/py311/lib/python3.11/site-packages/pandas/io/feather_format.py:123: FutureWarning: pyarrow.feather.read_feather is deprecated as of 24.0.0. Use pyarrow.ipc.open_file() / RecordBatchFileReader instead. Feather V2 is the Arrow IPC file format.
#   return feather.read_feather(

# %%
# extract TSS for gene_symbol
tss_df = gene_annotation.extract_tss(gtf)
gene_tss_df = tss_df[tss_df.gene_name == TARGET_GENE]

# %% [markdown]
# # Helper functions for regulatory peaks
#
# All peak-calling helpers live here: track filtering, signal utilities, isolation, containment collapse, BED conversion, overlay color mapping, and ENCODE-style cCRE classification. Run/viz cells below only call these.

# %% [markdown]
# ## Signal utilities
#
# `select_tracks` filters by tissue/name/strand; `collapse_tracks` and `zscore` reduce multi-track signal to a comparable 1D profile; `threshold_bins`, `bins_to_intervals`, `merge_nearby`, and `annotate_peak_scores` turn that profile into scored genomic intervals.

# %%
def select_tracks(tdata, *, tissue_curie=None, name_contains=None, strand=None):
    """Filter a multi-track TrackData object by tissue/name/strand metadata.

    Takes TrackData (same genomic bins, many tracks) plus optional filters and
    returns a TrackData subset with matching tracks only, or None if none match.
    """
    # Nothing to filter if the modality was missing from the prediction output
    if tdata is None:
        return None
    md = tdata.metadata
    # Start with all tracks selected; each filter below ANDs onto this mask
    mask = pd.Series(True, index=md.index)
    # Keep only tracks from the requested tissue ontology (e.g. LV heart)
    if tissue_curie is not None and "ontology_curie" in md.columns:
        mask &= md["ontology_curie"] == tissue_curie
    # Substring match on track name (e.g. histone mark like "H3K27ac")
    if name_contains is not None:
        mask &= md["name"].str.contains(name_contains, case=False, na=False)
    # Restrict to a single strand when requested (+ / -)
    if strand is not None:
        mask &= md["strand"] == strand
    # Caller treats None as "skip this modality"
    if not mask.any():
        return None
    return tdata.filter_tracks(mask.to_numpy())


def collapse_tracks(tdata, how="max"):
    """Reduce multi-track values to a single 1D genomic profile.

    Takes TrackData with values shaped (bins, tracks) and returns a length-bins
    array by taking max or mean across tracks (or None if empty).
    """
    if tdata is None or tdata.num_tracks == 0:
        return None
    vals = tdata.values  # shape: (n_bins, n_tracks)
    # Collapse across tracks (axis=1) so each bin has one summary value
    if how == "max":
        return vals.max(axis=1)
    if how == "mean":
        return vals.mean(axis=1)
    raise ValueError(how)


def zscore(x):
    """Standardize a 1D signal to mean 0 / sd 1 for cross-modality comparison.

    Takes a numeric array and returns a same-length z-scored array. If variance
    is zero, returns all zeros so this profile cannot dominate a later max-across-modality.
    """
    mu, sd = x.mean(), x.std()
    # Avoid divide-by-zero: flat signals contribute nothing after z-scoring
    return (x - mu) / sd if sd > 0 else x * 0


def threshold_bins(signal, method="percentile", value=95):
    """Mark high-scoring bins using a percentile, std, or absolute cutoff.

    Takes a 1D signal and a threshold rule; returns (boolean mask of high bins,
    numeric cutoff used).
    """
    if method == "percentile":
        # value is a percentile in [0, 100], e.g. 95 -> keep top 5% of bins
        cutoff = np.percentile(signal, value)
    elif method == "std":
        # value is the number of SDs above the mean
        cutoff = signal.mean() + value * signal.std()
    else:
        # Treat value as an absolute signal cutoff
        cutoff = value
    return signal >= cutoff, cutoff


def bins_to_intervals(signal, mask, interval, resolution):
    """Convert runs of high bins into genomic Interval objects.

    Takes a 1D signal, a boolean high-bin mask, and the genomic interval plus
    bin resolution; returns merged genome.Interval objects in chromosome coords.
    (signal is unused for calling but kept for API consistency with callers.)
    """
    regions = []
    in_region = False
    start_bin = None

    # Run-length encode consecutive True bins into [start_bin, end_bin) pairs
    for i, is_high in enumerate(mask):
        if is_high and not in_region:
            # Entering a new high-signal run
            start_bin = i
            in_region = True
        elif not is_high and in_region:
            # Leaving a run: end is exclusive (current i)
            regions.append((start_bin, i))
            in_region = False
    # Close a run that extends to the last bin
    if in_region:
        regions.append((start_bin, len(mask)))

    intervals = []
    for b0, b1 in regions:
        # Map bin indices back to genomic coordinates within the prediction window
        start = interval.start + b0 * resolution
        end = interval.start + b1 * resolution
        intervals.append(genome.Interval(interval.chromosome, start, end))
    return intervals


def merge_nearby(intervals, gap=200):
    """Merge genomic intervals that fall within gap bp of each other.

    Takes a list of intervals and returns fewer, wider intervals by merging any
    whose start is within `gap` bp of the previous end.
    """
    if not intervals:
        return []
    # Sort so we only need a single left-to-right pass
    intervals = sorted(intervals, key=lambda x: x.start)
    merged = [intervals[0]]
    for iv in intervals[1:]:
        prev = merged[-1]
        # If this interval starts within `gap` bp of the previous end, fuse them
        if iv.start - prev.end <= gap:
            merged[-1] = genome.Interval(
                prev.chromosome, prev.start, max(prev.end, iv.end)
            )
        else:
            merged.append(iv)
    return merged


def annotate_peak_scores(intervals, signal, interval, resolution):
    """Attach max/mean signal scores to each called interval from the 1D profile.

    Takes called intervals plus the signal they came from; writes max_signal and
    mean_signal into each interval's .info from overlapping bins, then returns
    intervals sorted by max_signal descending.
    """
    for iv in intervals:
        # Convert genomic coords back to bin indices within the anchor window
        b0 = (iv.start - interval.start) // resolution
        b1 = (iv.end - interval.start) // resolution
        iv.info["max_signal"] = float(signal[b0:b1].max())
        iv.info["mean_signal"] = float(signal[b0:b1].mean())
    # Strongest peaks first for downstream ranking / BED export
    return sorted(intervals, key=lambda x: x.info["max_signal"], reverse=True)

# %% [markdown]
# ## Isolate high regions (multi-modality max z-score)
#
# `isolate_high_regulatory_regions` selects LV tracks (optionally filtered by `histone_mark`), collapses and z-scores them at 128 bp, takes the max across modalities, thresholds (default 95th percentile), filters by width, merges nearby peaks, and annotates scores.

# %%
def isolate_high_regulatory_regions(
    output,
    *,
    tissue_curie=LV_UB,
    modalities=("dnase", "cage", "chip_histone"),
    histone_mark=None,
    collapse="max",
    resolution_bp=128,
    threshold_method="percentile",
    threshold_value=95,
    min_width_bp=500,
    merge_gap_bp=1,):
    """Call high-signal regulatory intervals from multi-modality AlphaGenome output.

    Takes prediction `output` (dnase/atac/chip/cage TrackData) plus calling
    parameters; selects tissue tracks per modality, collapses+z-scores each to
    a common resolution, takes the per-bin max across modalities, thresholds to
    peaks, filters/merges, and returns scored intervals with the combined signal,
    cutoff, and genomic anchor used for calling.
    """

    # One z-scored 1D profile per modality that had matching tracks
    profiles = []
    # Genomic window shared by all resampled tracks (set inside process)
    anchor_interval = None
    anchor_resolution = resolution_bp

    def process(tdata):
        """Resample, collapse, and z-score one modality's TrackData into profiles."""
        nonlocal anchor_interval
        if tdata is None or tdata.num_tracks == 0:
            return
        # Resample all modalities to the same bin size before combining
        tdata = tdata.change_resolution(resolution_bp)
        # Reduce (bins, tracks) -> (bins,) using max or mean across tracks
        collapsed = collapse_tracks(tdata, collapse)
        if collapsed is None:
            return
        # Remember the genomic window so later bin->coord conversion is consistent
        anchor_interval = tdata.interval
        # Z-score so modalities with different dynamic ranges are comparable
        profiles.append(zscore(collapsed))

    # Build filtered TrackData for each modality name the caller might request
    modality_map = {
        "dnase": select_tracks(output.dnase, tissue_curie=tissue_curie),
        "atac": select_tracks(output.atac, tissue_curie=tissue_curie),
        # Optional name_contains filters to a specific histone mark (e.g. H3K27ac)
        "chip_histone": select_tracks(
            output.chip_histone,
            tissue_curie=tissue_curie,
            name_contains=histone_mark,
        ),
        "chip_tf": select_tracks(output.chip_tf, tissue_curie=tissue_curie),
        "cage": select_tracks(output.cage, tissue_curie=tissue_curie, strand='+'), # only pos strand b/c LMNA is on + strand only
    }

    # Process only the modalities requested by the caller
    for m in modalities:
        # print(m)
        process(modality_map[m])

    if not profiles:
        raise ValueError(
            f"No tracks matched filters for modalities={list(modalities)}, "
            f"tissue_curie={tissue_curie}, histone_mark={histone_mark}"
        )

    # Stack modality profiles as columns, then take the max at each bin
    signal = np.stack(profiles, axis=1).max(axis=1)
    # print(signal[:10])
    # Boolean mask of high bins under the chosen threshold rule
    mask, cutoff = threshold_bins(signal, threshold_method, threshold_value)

    # Turn consecutive high bins into genome.Interval objects
    intervals = bins_to_intervals(signal, mask, anchor_interval, anchor_resolution)

    # Discard narrow peaks below the minimum width
    intervals = [iv for iv in intervals if iv.width >= min_width_bp]

    # Fuse peaks that fall within merge_gap_bp of each other
    intervals = merge_nearby(intervals, merge_gap_bp)

    # Attach max/mean signal scores and rank by peak strength
    intervals = annotate_peak_scores(intervals, signal, anchor_interval, anchor_resolution)

    return {
        "intervals": intervals,
        "signal": signal,
        "cutoff": cutoff,
        "resolution": anchor_resolution,
        "anchor_interval": anchor_interval,
    }

# %% [markdown]
# ## Collapse, BED, and color helpers
#
# `collapse_contained_intervals` builds parent/member tables for nested peaks. `intervals_to_bed_df` formats peaks for export. `load_bed_intervals` plus `category_from_name` / `color_from_category` prepare colored overlays.

# %%
def collapse_contained_intervals(df):
    """Collapse completely nested (or identical) intervals into parent + member tables.

    Only complete containment is collapsed; partial overlaps stay as separate parents.
    Every input row appears exactly once in the members table.
    """
    # --- Step 1: copy input and give each row a stable identity ---
    # Work on a copy so we never mutate the caller's DataFrame.
    # interval_id is assigned from the original row order (before sorting).
    work = df.copy().reset_index(drop=True)
    work["interval_id"] = [f"iv_{i}" for i in range(len(work))]
    # Width is used later to pick the tightest containing parent among candidates.
    work["width"] = work["end"] - work["start"]

    # --- Step 2: sort so larger / left-er intervals are considered first ---
    # Per chromosome:
    #   - ascending start  → intervals that begin earlier come first
    #   - descending end   → among equal starts, wider (larger end) comes first
    #   - ascending interval_id → deterministic tie-break for identical spans
    # mergesort keeps the sort stable if other ties remain.
    work = work.sort_values(
        ["chrom", "start", "end", "interval_id"],
        ascending=[True, True, False, True],
        kind="mergesort",
    ).reset_index(drop=True)

    # parents: maximal outer intervals discovered so far (not nested in another parent)
    # assignments: (parent_id, row_dict, is_parent) for every input interval
    parents = []
    assignments = []

    def contains(outer, inner):
        """True iff outer completely contains inner (same chrom), including identical spans."""
        return (
            outer["chrom"] == inner["chrom"]
            and outer["start"] <= inner["start"]
            and outer["end"] >= inner["end"]
        )

    # --- Step 3: walk sorted intervals and assign each to a parent or as a new parent ---
    parent_counter = 0
    for _, row in work.iterrows():
        row = row.to_dict()
        # Which already-chosen parents fully contain this interval?
        containing = [p for p in parents if contains(p, row)]
        if containing:
            # Nested (or identical to an existing parent): attach as a member.
            # Prefer the tightest nest — smallest width, then earliest start, then lowest id.
            parent = min(
                containing,
                key=lambda p: (p["width"], p["start"], p["interval_id"]),
            )
            assignments.append((parent["parent_id"], row, False))
        else:
            # Not contained in any parent yet → this interval is a new outer parent.
            # (Partial overlaps with existing parents do not count as containment.)
            parent_id = f"parent_{parent_counter}"
            parent_counter += 1
            parent = {
                "parent_id": parent_id,
                "chrom": row["chrom"],
                "start": int(row["start"]),
                "end": int(row["end"]),
                "name": row["name"],
                "score": row["score"],
                "width": int(row["width"]),
                "interval_id": row["interval_id"],
            }
            parents.append(parent)
            # Record the parent interval itself as a member with is_parent=True.
            assignments.append((parent_id, row, True))

    # --- Step 4: build the members (child) table ---
    # One row per input interval, linked to its parent_id.
    # is_parent marks the outer/maximal interval for that group.
    member_rows = []
    for parent_id, row, is_parent in assignments:
        member_rows.append(
            {
                "parent_id": parent_id,
                "interval_id": row["interval_id"],
                "chrom": row["chrom"],
                "start": int(row["start"]),
                "end": int(row["end"]),
                "name": row["name"],
                "score": row["score"],
                "is_parent": is_parent,
            }
        )
    members_df = pd.DataFrame(member_rows)

    # --- Step 5: build the collapsed parent table ---
    # One row per parent; n_members includes the parent row itself.
    # member_names is a convenience join of all member names under that parent.
    parent_rows = []
    for p in parents:
        mem = members_df[members_df["parent_id"] == p["parent_id"]]
        parent_rows.append(
            {
                "parent_id": p["parent_id"],
                "chrom": p["chrom"],
                "start": p["start"],
                "end": p["end"],
                "name": p["name"],
                "score": p["score"],
                "n_members": len(mem),
                "member_names": ";".join(mem["name"].astype(str).tolist()),
            }
        )
    collapsed_df = pd.DataFrame(parent_rows)

    # Return (parents, members). Standalone intervals appear in both (n_members == 1).
    return collapsed_df, members_df


def intervals_to_bed_df(intervals, name_prefix):
    """Build a chrom/start/end/name/score DataFrame from genome.Interval peaks."""
    return pd.DataFrame(
        [
            {
                "chrom": iv.chromosome,
                "start": iv.start,
                "end": iv.end,
                "name": f"{name_prefix}_{k}",
                "score": iv.info.get("max_signal"),
            }
            for k, iv in enumerate(intervals)
        ]
    )

def load_bed_intervals(bed_path, plot_interval=None):
    df = pd.read_csv(bed_path, sep='\t')
    intervals = [
        genome.Interval(
            chromosome=row.chrom,
            start=int(row.start),
            end=int(row.end),
            name=row['name'],
            info={'score': row.score},
        )
        for _, row in df.iterrows()
    ]
    num_intervals = len(intervals)
    if plot_interval is not None:
        intervals = [iv for iv in intervals if plot_interval.contains(iv)]
        print(f'loaded {num_intervals} intervals from bed file that fall within {plot_interval}!')
    else:
        print(f'loaded {num_intervals} intervals from bed file')
    return intervals, df


# Longer keys first so chip_histone / chip_tf / rna_seq match before shorter tokens
MODALITIES = sorted(MODALITY_COLORS, key=len, reverse=True)


def category_from_name(name: str) -> str:
    name = str(name)
    for mark in HISTONE_MARKS:
        if mark in name:
            return mark
    for modality in MODALITIES:
        if modality in name:
            return modality
    return "other"


def color_from_category(cat: str) -> str:
    if cat in HISTONE_COLORS:
        return HISTONE_COLORS[cat]
    return MODALITY_COLORS.get(cat, "gray")

# %% [markdown]
# ## cCRE-like classification helpers
#
# Build per-modality z-scored profiles (DNase / H3K4me3 / H3K27ac / CTCF / other TF), call candidate peaks from high chromatin accessibility (plus TF-only sites), score high/low flags and nearest-TSS distance, then assign an ENCODE-style `cCRE_class` via a priority decision tree.
#
# **Approximation:** high/low use within-window percentiles on AlphaGenome predictions, not ENCODE genome-wide max-Z cutoffs.

# %%
def profile_for(
    output,
    *,
    modality,
    tissue_curie=LV_UB,
    histone_mark=None,
    name_contains=None,
    exclude_name_contains=None,
    strand=None,
    collapse="max",
    resolution_bp=128,
    threshold_method="percentile",
    threshold_value=95,
):
    """Build one z-scored 1D profile and a within-window high-bin mask.

    Takes AlphaGenome `output` plus a modality name (and optional track filters);
    selects LV tracks, resamples/collapses/z-scores them, thresholds with a
    within-window percentile (ENCODE approximation — not genome-wide max-Z),
    and returns a dict with signal, high_mask, cutoff, anchor_interval, resolution.
    Returns None if no matching tracks exist.
    """
    # --- Select tracks for this ENCODE-style signal axis ---
    if modality == "dnase":
        # Chromatin accessibility (CA): plus-strand DNase for LV
        tdata = select_tracks(
            output.dnase, tissue_curie=tissue_curie
        )
    elif modality == "chip_histone":
        # Histone mark filter via name substring (e.g. H3K4me3, H3K27ac)
        tdata = select_tracks(
            output.chip_histone,
            tissue_curie=tissue_curie,
            name_contains=histone_mark or name_contains,
        )
    elif modality == "chip_tf":
        # TF ChIP; name_contains can restrict to CTCF, etc.
        tdata = select_tracks(
            output.chip_tf,
            tissue_curie=tissue_curie,
            name_contains=name_contains,
        )
        # For "other TF" profile, drop CTCF so it is not double-counted as TF+CTCF
        if tdata is not None and exclude_name_contains is not None:
            md = tdata.metadata
            keep = ~md["name"].str.contains(
                exclude_name_contains, case=False, na=False
            )
            if not keep.any():
                return None
            tdata = tdata.filter_tracks(keep.to_numpy())
    elif modality == "atac":
        tdata = select_tracks(output.atac, tissue_curie=tissue_curie)
    else:
        raise ValueError(f"Unsupported modality for profile_for: {modality}")

    if tdata is None or tdata.num_tracks == 0:
        return None

    # Align bin size across modalities before combining / classifying
    tdata = tdata.change_resolution(resolution_bp)
    collapsed = collapse_tracks(tdata, collapse)
    if collapsed is None:
        return None

    # Z-score within the prediction window so modalities are comparable
    signal = zscore(collapsed)
    # High bins ≈ ENCODE "high signal"; cutoff is window-local, not genome-wide
    high_mask, cutoff = threshold_bins(signal, threshold_method, threshold_value)
    print(high_mask)

    return {
        "signal": signal,
        "high_mask": high_mask,
        "cutoff": cutoff,
        "anchor_interval": tdata.interval,
        "resolution": resolution_bp,
    }


def tss_positions_from_df(tss_df, chrom):
    """Load TSS coordinates for one chromosome from notebook `tss_df`.

    Takes the DataFrame from `gene_annotation.extract_tss(gtf)` (point
    intervals with start == end == TSS) and a chromosome name such as
    'chr1'; normalizes 'chr' prefixes, and returns a sorted int64 array
    of TSS positions (using start).
    """
    # extract_tss may use Chromosome/Start or chrom/start depending on GTF schema
    chrom_col = "Chromosome" if "Chromosome" in tss_df.columns else "chrom"
    start_col = "Start" if "Start" in tss_df.columns else "start"

    # GTF may use '1' while AlphaGenome intervals use 'chr1'
    chrom_raw = str(chrom).removeprefix("chr")
    chrom_chr = f"chr{chrom_raw}"
    mask = tss_df[chrom_col].astype(str).isin([chrom_raw, chrom_chr, str(chrom)])
    positions = tss_df.loc[mask, start_col].astype(np.int64).to_numpy()
    positions.sort()
    return positions


def nearest_tss_distance(start, end, tss_arr):
    """Distance from peak midpoint to the nearest annotated TSS.

    Takes genomic start/end and a sorted TSS position array; returns the
    absolute bp distance (np.inf if no TSS are available).
    """
    if tss_arr is None or len(tss_arr) == 0:
        return np.inf
    # ENCODE distance rules use proximity of the element to a TSS
    mid = (int(start) + int(end)) // 2
    return int(np.min(np.abs(tss_arr.astype(np.int64) - mid)))


def peak_high_flags(iv, high_masks, anchor_interval, resolution):
    """Score high/low ENCODE-style flags for one peak from high-bin masks.

    Takes a peak `genome.Interval`, a dict of modality→boolean bin masks
    aligned to `anchor_interval`, and bin resolution; returns a dict of
    high_* booleans True if the peak overlaps ≥1 high bin for that modality.
    """
    # Map peak genomic span back to bin indices in the prediction window
    b0 = (iv.start - anchor_interval.start) // resolution
    b1 = (iv.end - anchor_interval.start) // resolution
    flags = {}
    for key, mask in high_masks.items():
        b0c = max(0, int(b0))
        b1c = min(len(mask), int(b1))
        # Overlap of any high bin ⇒ "high" for this signal (ENCODE joint criteria)
        flags[key] = bool(mask[b0c:b1c].any()) if b1c > b0c else False
    return flags


def assign_ccre_class(flags, d_tss):
    """Assign one ENCODE-style cCRE class from high/low flags and TSS distance.

    Takes a flags dict (high_CA / high_H3K4me3 / high_H3K27ac / high_CTCF /
    high_TF) and nearest-TSS distance in bp; returns a class label string
    using the priority order from ENCODE cCRE definitions.
    """
    high_CA = bool(flags.get("high_CA", False))
    high_H3K4me3 = bool(flags.get("high_H3K4me3", False))
    high_H3K27ac = bool(flags.get("high_H3K27ac", False))
    high_CTCF = bool(flags.get("high_CTCF", False))
    high_TF = bool(flags.get("high_TF", False))

    # 1) Promoter-like: CA + H3K4me3 within 200 bp of a TSS
    if high_CA and high_H3K4me3 and d_tss <= 200:
        return "Promoter"

    # 2) Proximal enhancer: CA + H3K27ac within 2 kb of TSS.
    #    Within 200 bp + high H3K4me3 already returned as Promoter above, so
    #    remaining ≤2 kb peaks satisfy ENCODE's "low H3K4me3 if ≤200 bp" rule.
    if high_CA and high_H3K27ac and d_tss <= 2000:
        return "Proximal enhancer"

    # 3) Distal enhancer: CA + H3K27ac and farther than 2 kb from TSS
    if high_CA and high_H3K27ac and d_tss > 2000:
        return "Distal enhancer"

    # 4) CA-H3K4me3: CA + H3K4me3, low H3K27ac, not within 200 bp of TSS
    if high_CA and high_H3K4me3 and (not high_H3K27ac) and d_tss > 200:
        return "CA-H3K4me3"

    # 5) CA-CTCF: CA + CTCF with low H3K4me3 and low H3K27ac
    if high_CA and high_CTCF and (not high_H3K4me3) and (not high_H3K27ac):
        return "CA-CTCF"

    # 6) CA-TF: CA + other TF, low H3K4me3 / H3K27ac / CTCF
    if (
        high_CA
        and high_TF
        and (not high_H3K4me3)
        and (not high_H3K27ac)
        and (not high_CTCF)
    ):
        return "CA-TF"

    # 7) CA alone: accessible chromatin without the marks above
    if high_CA and (not high_H3K4me3) and (not high_H3K27ac) and (not high_CTCF):
        return "CA"

    # 8) TF alone: TF-bound with low CA and low histone/CTCF marks
    if (
        (not high_CA)
        and high_TF
        and (not high_H3K4me3)
        and (not high_H3K27ac)
        and (not high_CTCF)
    ):
        return "TF"

    # Peak did not match a defined combinatorial class
    return "Unclassified"


def classify_ccre_like_regions(
    output,
    *,
    tss_df,
    tissue_curie=LV_UB,
    resolution_bp=128,
    threshold_method="percentile",
    threshold_value=95,
    min_width_bp=500,
    merge_gap_bp=1,
):
    """Call and classify ENCODE-style cCRE-like intervals from AlphaGenome output.

    Takes prediction `output` and notebook `tss_df` from
    `gene_annotation.extract_tss(gtf)`; builds DNase/H3K4me3/H3K27ac/CTCF/TF
    profiles, seeds peaks from high CA (and high-TF ∩ low-CA for TF-only),
    scores joint high/low flags + d_tss, assigns `cCRE_class`, and returns
    classified intervals plus profile metadata.
    """
    # Shared kwargs for within-window high/low thresholding (ENCODE approximation)
    thr = dict(
        tissue_curie=tissue_curie,
        resolution_bp=resolution_bp,
        threshold_method=threshold_method,
        threshold_value=threshold_value,
    )

    # --- Build the five signal axes used by ENCODE cCRE rules ---
    ca = profile_for(output, modality="dnase", strand="+", **thr)
    k4 = profile_for(output, modality="chip_histone", histone_mark="H3K4me3", **thr)
    k27 = profile_for(output, modality="chip_histone", histone_mark="H3K27ac", **thr)
    ctcf = profile_for(output, modality="chip_tf", name_contains="CTCF", **thr)
    # Other TFs: all LV chip_tf except CTCF
    tf = profile_for(
        output, modality="chip_tf", exclude_name_contains="CTCF", **thr
    )

    if ca is None:
        raise ValueError("No DNase (CA) tracks matched; cannot seed cCRE-like peaks")

    anchor = ca["anchor_interval"]
    res = ca["resolution"]

    # Collect high-bin masks; missing modalities default to all-False (always "low")
    n_bins = len(ca["signal"])
    false_mask = np.zeros(n_bins, dtype=bool)

    high_masks = {
        "high_CA": ca["high_mask"],
        "high_H3K4me3": k4["high_mask"] if k4 is not None else false_mask,
        "high_H3K27ac": k27["high_mask"] if k27 is not None else false_mask,
        "high_CTCF": ctcf["high_mask"] if ctcf is not None else false_mask,
        "high_TF": tf["high_mask"] if tf is not None else false_mask,
    }

    # --- Seed candidates ---
    # Classes 1–7 require high CA: call peaks from the DNase high mask
    ca_intervals = bins_to_intervals(ca["signal"], ca["high_mask"], anchor, res)
    ca_intervals = [iv for iv in ca_intervals if iv.width >= min_width_bp] # filter out intervals that do not meet min bp
    ca_intervals = merge_nearby(ca_intervals, merge_gap_bp)
    # Rank/score CA peaks on the accessibility profile
    ca_intervals = annotate_peak_scores(ca_intervals, ca["signal"], anchor, res)

    # Class 8 (TF): also seed from high TF where CA is low so TF-only sites are kept
    tf_only_intervals = []
    if tf is not None:
        tf_only_mask = tf["high_mask"] & (~ca["high_mask"])
        tf_only_intervals = bins_to_intervals(
            tf["signal"], tf_only_mask, anchor, res
        )
        tf_only_intervals = [
            iv for iv in tf_only_intervals if iv.width >= min_width_bp
        ]
        tf_only_intervals = merge_nearby(tf_only_intervals, merge_gap_bp)
        tf_only_intervals = annotate_peak_scores(
            tf_only_intervals, tf["signal"], anchor, res
        )

    # Union of CA-seeded and TF-only-seeded peaks (classify each independently)
    candidates = list(ca_intervals) + list(tf_only_intervals)

    # --- TSS distances for promoter vs proximal/distal enhancer splits ---
    # Use notebook tss_df (extract_tss) rather than re-deriving from GTF/BED
    chrom = anchor.chromosome
    tss_arr = tss_positions_from_df(tss_df, chrom)

    classified = []
    for iv in candidates:
        # Joint high/low flags for this peak span
        flags = peak_high_flags(iv, high_masks, anchor, res)
        d_tss = nearest_tss_distance(iv.start, iv.end, tss_arr)
        ccre_class = assign_ccre_class(flags, d_tss)

        # Attach ENCODE-style labels and diagnostics onto the interval
        iv.info["cCRE_class"] = ccre_class
        iv.info["d_tss"] = d_tss
        iv.info.update(flags)
        # Keep modality peak heights when profiles exist (for BED score / QC)
        for key, prof, label in [
            ("max_CA", ca, "signal"),
            ("max_H3K4me3", k4, "signal"),
            ("max_H3K27ac", k27, "signal"),
            ("max_CTCF", ctcf, "signal"),
            ("max_TF", tf, "signal"),
        ]:
            if prof is None:
                iv.info[key] = np.nan
                continue
            b0 = (iv.start - anchor.start) // res
            b1 = (iv.end - anchor.start) // res
            b0c, b1c = max(0, int(b0)), min(len(prof["signal"]), int(b1))
            iv.info[key] = (
                float(prof["signal"][b0c:b1c].max()) if b1c > b0c else np.nan
            )

        classified.append(iv)

    # Strongest CA (or TF) score first for stable export ordering
    classified = sorted(
        classified,
        key=lambda x: x.info.get("max_signal", x.info.get("max_CA", 0.0)),
        reverse=True,
    )

    return {
        "intervals": classified,
        "profiles": {"CA": ca, "H3K4me3": k4, "H3K27ac": k27, "CTCF": ctcf, "TF": tf},
        "anchor_interval": anchor,
        "resolution": res,
        "tss_count": int(len(tss_arr)),
    }


def ccre_intervals_to_bed_df(intervals, name_prefix="pred_ccre"):
    """Build an export table from classified cCRE-like intervals.

    Takes classified `genome.Interval` objects with cCRE info fields; returns a
    DataFrame with coordinates, class, d_tss, high flags, and modality scores.
    """
    rows = []
    for k, iv in enumerate(intervals):
        rows.append(
            {
                "chrom": iv.chromosome,
                "start": iv.start,
                "end": iv.end,
                "name": f"{name_prefix}_{k}_{iv.info.get('cCRE_class', 'NA')}",
                "score": iv.info.get("max_signal", iv.info.get("max_CA")),
                "cCRE_class": iv.info.get("cCRE_class"),
                "d_tss": iv.info.get("d_tss"),
                "high_CA": iv.info.get("high_CA"),
                "high_H3K4me3": iv.info.get("high_H3K4me3"),
                "high_H3K27ac": iv.info.get("high_H3K27ac"),
                "high_CTCF": iv.info.get("high_CTCF"),
                "high_TF": iv.info.get("high_TF"),
                "max_CA": iv.info.get("max_CA"),
                "max_H3K4me3": iv.info.get("max_H3K4me3"),
                "max_H3K27ac": iv.info.get("max_H3K27ac"),
                "max_CTCF": iv.info.get("max_CTCF"),
                "max_TF": iv.info.get("max_TF"),
            }
        )
    return pd.DataFrame(rows)

# %% [markdown]
# # Predict interval
#
# Define 1 Mb PRE, POST, and central windows around LMNA, set `interval = POST_INTERVAL` and `gene_context = 'post'`, choose LV ontology terms, run `model.predict_interval`, and extract `longest_transcripts` in that window for later plotting.

# %%
# Define interval to make predictions for (used throughout this tutorial).
# Note that the interval width must be one of the supported sequence lengths.

CENTRAL_INTERVAL = GENE_INTERVAL.resize(
    dna_client.SEQUENCE_LENGTH_1MB)

########################### INPUT VARIABLES HERE
interval = CENTRAL_INTERVAL
gene_context = 'gene_centered_interval'
###########################


print(gene_context)
print(interval)

# Extract the longest transcripts per gene for this interval.
longest_transcripts = longest_transcript_extractor.extract(interval)

# Define the tissues/cell-types to predict expression for.
ontology_terms = [
    # 'UBERON:0000948',  # heart
    # 'UBERON:0002080', # heart RV
    'UBERON:0002084', # heart LV
]

# Make predictions.
output = model.predict_interval(
    interval=interval,
    requested_outputs=requested_outputs,
    ontology_terms=ontology_terms,
)
print("prediction finished")
# Out:
# gene_centered_interval
# chr6:7039733-8088309:+
# prediction finished

# %% [markdown]
# # Isolate and export candidate regions
#
# Call high-signal intervals from the prediction `output`, export an indiv-tracks BED, then collapse completely nested intervals into parent/member tables for cleaner overlays.

# %% [markdown]
# ## Per-modality / per-histone-mark regions
#
# Isolate peaks for DNase and CAGE alone; for `chip_histone`, loop over each mark in `HISTONE_MARKS`. Build `pred_regions_df` via `intervals_to_bed_df` and optionally write the indiv-tracks BED. Saves the peaks as candidate regulatory regions- does NOT use the ENCODE classifications

# %%
modalities = ["dnase", "cage", "chip_histone"]

save = True
df_list = []

for mod_i, modality in enumerate(modalities):
    print(modality)
    if modality == "chip_histone":
        for histone_marker in HISTONE_MARKS:
            print(histone_marker)
            try:
                result = isolate_high_regulatory_regions(
                    output, modalities=[modality], histone_mark=histone_marker
                )
            except ValueError as e:
                print(f"  skipping {histone_marker}: {e}")
                continue
            output_df = intervals_to_bed_df(
                result["intervals"],
                f"pred_reg_{gene_context}_{modality}_{mod_i}_{histone_marker}",
            )
            df_list.append(output_df)
    else:
        result = isolate_high_regulatory_regions(output, modalities=[modality])
        output_df = intervals_to_bed_df(
            result["intervals"],
            f"pred_reg_{gene_context}_{modality}_{mod_i}",
        )
        df_list.append(output_df)

pred_regions_df = pd.concat(df_list)
pred_regions_df

if save:
    pred_regions_df.to_csv(
        f"outputs/predicted_reg_regions_{gene_context}_indivtracks_LV_128res.bed",
        index=False,
        sep="\t",
    )
    print("saved!")
# Out:
# dnase
# cage
# chip_histone
# H3K4me3
# H3K4me1
# H3K9ac
#   skipping H3K9ac: No tracks matched filters for modalities=['chip_histone'], tissue_curie=UBERON:0002084, histone_mark=H3K9ac
# H3K27ac
# H3K36me3
# H3K9me3
# H3K27me3
# saved!

# %% [markdown]
# ## Collapse completely nested intervals
#
# Run `collapse_contained_intervals` on `pred_regions_df` and print parent/member summary counts.

# %%
pred_regions_collapsed_df, pred_regions_members_df = collapse_contained_intervals(
    pred_regions_df
)

n_input = len(pred_regions_df)
n_parents = len(pred_regions_collapsed_df)
n_nested = int((~pred_regions_members_df["is_parent"]).sum())
print(
    f"n_input={n_input}, n_parents={n_parents}, n_nested={n_nested}, "
    f"n_members={len(pred_regions_members_df)}"
)
assert len(pred_regions_members_df) == n_input
assert set(pred_regions_members_df["parent_id"]) <= set(
    pred_regions_collapsed_df["parent_id"]
)

print("\n--- collapsed parents ---")
print(pred_regions_collapsed_df.to_string())
print("\n--- members ---")
print(pred_regions_members_df.to_string())
# Out:
# n_input=217, n_parents=140, n_nested=77, n_members=217
#
# --- collapsed parents ---
#       parent_id chrom    start      end                                                        name      score  n_members                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       member_names
# 0      parent_0  chr6  7042421  7042933   pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_18   0.368630          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_18
# 1      parent_1  chr6  7042549  7043061   pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_22   1.429284          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_22
# 2      parent_2  chr6  7042677  7043189   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_25   3.179490          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_25
# 3      parent_3  chr6  7043317  7043829   pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_26   1.129082          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_26
# 4      parent_4  chr6  7050613  7053301    pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_6   8.471953          5                                                                                                                                                                                                                                                                                    pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_6;pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_5;pred_reg_gene_centered_interval_dnase_0_11;pred_reg_gene_centered_interval_cage_1_7;pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_22
# 5      parent_5  chr6  7073653  7074165   pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_20   0.158822          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_20
# 6      parent_6  chr6  7086197  7087605   pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_11   1.599765          2                                                                                                                                                                                                                                                                                                                                                                                                                                pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_11;pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_24
# 7      parent_7  chr6  7106293  7110133    pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_2  14.583601          4                                                                                                                                                                                                                                                                                                                                              pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_2;pred_reg_gene_centered_interval_cage_1_1;pred_reg_gene_centered_interval_dnase_0_9;pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_27
# 8      parent_8  chr6  7106549  7111413    pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_1  14.045710          2                                                                                                                                                                                                                                                                                                                                                                                                                                 pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_1;pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_35
# 9      parent_9  chr6  7110901  7113333   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_23   3.289797          3                                                                                                                                                                                                                                                                                                                                                                      pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_23;pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_13;pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_20
# 10    parent_10  chr6  7114101  7116661   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_13   3.657488          2                                                                                                                                                                                                                                                                                                                                                                                                                                pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_13;pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_17
# 11    parent_11  chr6  7136757  7139317   pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_12   3.148624          3                                                                                                                                                                                                                                                                                                                                                                       pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_12;pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_3;pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_17
# 12    parent_12  chr6  7139829  7143669    pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_1  15.784410          4                                                                                                                                                                                                                                                                                                                               pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_1;pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_7;pred_reg_gene_centered_interval_dnase_0_4;pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_6
# 13    parent_13  chr6  7142261  7143797   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_28   3.069183          2                                                                                                                                                                                                                                                                                                                                                                                                                                               pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_28;pred_reg_gene_centered_interval_dnase_0_15
# 14    parent_14  chr6  7144693  7148277   pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_10   5.713989          4                                                                                                                                                                                                                                                                                                                            pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_10;pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_5;pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_14;pred_reg_gene_centered_interval_dnase_0_13
# 15    parent_15  chr6  7150581  7151093   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_29   3.069183          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_29
# 16    parent_16  chr6  7151349  7151861   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_19   3.400105          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_19
# 17    parent_17  chr6  7155189  7157621   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_17   3.473643          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_17
# 18    parent_18  chr6  7163893  7167221    pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_2   4.834098          2                                                                                                                                                                                                                                                                                                                                                                                                                                 pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_2;pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_16
# 19    parent_19  chr6  7168373  7171829    pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_0   5.569480          3                                                                                                                                                                                                                                                                                                                                                                                      pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_0;pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_15;pred_reg_gene_centered_interval_dnase_0_12
# 20    parent_20  chr6  7172341  7173493   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_18   3.436874          2                                                                                                                                                                                                                                                                                                                                                                                                                                pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_18;pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_21
# 21    parent_21  chr6  7175285  7176437   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_32   2.848568          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_32
# 22    parent_22  chr6  7175413  7176821   pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_19   1.674904          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_19
# 23    parent_23  chr6  7181045  7182069                    pred_reg_gene_centered_interval_cage_1_9   0.140480          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           pred_reg_gene_centered_interval_cage_1_9
# 24    parent_24  chr6  7181429  7182197  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_23   3.005330          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_23
# 25    parent_25  chr6  7187701  7188213  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_21   3.204226          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_21
# 26    parent_26  chr6  7188981  7189621   pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_5   4.139037          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_5
# 27    parent_27  chr6  7211381  7213045   pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_8   3.940141          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_8
# 28    parent_28  chr6  7213301  7214197  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_31   2.806434          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_31
# 29    parent_29  chr6  7216117  7218549   pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_13   2.548219          2                                                                                                                                                                                                                                                                                                                                                                                                                                pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_13;pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_12
# 30    parent_30  chr6  7217909  7218677   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_31   2.922107          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_31
# 31    parent_31  chr6  7219189  7220469   pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_14   2.248017          2                                                                                                                                                                                                                                                                                                                                                                                                                                pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_14;pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_10
# 32    parent_32  chr6  7226485  7227381  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_18   3.442901          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_18
# 33    parent_33  chr6  7228789  7232245   pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_0   6.247333          4                                                                                                                                                                                                                                                                                                                                                           pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_0;pred_reg_gene_centered_interval_cage_1_8;pred_reg_gene_centered_interval_dnase_0_21;pred_reg_gene_centered_interval_dnase_0_22
# 34    parent_34  chr6  7246197  7249397   pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_1   5.372191          4                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_1;pred_reg_gene_centered_interval_cage_1_12;pred_reg_gene_centered_interval_dnase_0_19;pred_reg_gene_centered_interval_dnase_0_18
# 35    parent_35  chr6  7248501  7251957                    pred_reg_gene_centered_interval_cage_1_5   2.670535          2                                                                                                                                                                                                                                                                                                                                                                                                                                                pred_reg_gene_centered_interval_cage_1_5;pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_28
# 36    parent_36  chr6  7255797  7256437   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_21   4.457790          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_21
# 37    parent_37  chr6  7260661  7262197   pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_10   6.856831          4                                                                                                                                                                                                                                                                                                            pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_10;pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_14;pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_11;pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_20
# 38    parent_38  chr6  7260789  7262325                   pred_reg_gene_centered_interval_dnase_0_7  10.639538          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_dnase_0_7
# 39    parent_39  chr6  7289077  7289973  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_19   3.423012          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_19
# 40    parent_40  chr6  7293429  7293941  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_32   2.587649          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_32
# 41    parent_41  chr6  7297397  7298037  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_13   3.681576          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_13
# 42    parent_42  chr6  7298421  7299701  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_11   3.721355          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_11
# 43    parent_43  chr6  7300597  7303029   pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_4   4.298153          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_4
# 44    parent_44  chr6  7308917  7309813  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_12   3.701466          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_12
# 45    parent_45  chr6  7310837  7314037    pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_0  14.615753          4                                                                                                                                                                                                                                                                                                                              pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_0;pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_26;pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_0;pred_reg_gene_centered_interval_dnase_0_0
# 46    parent_46  chr6  7352437  7353077   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_13   4.952494          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_13
# 47    parent_47  chr6  7388789  7391733    pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_4  11.702198          5                                                                                                                                                                                                                                                                                      pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_4;pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_3;pred_reg_gene_centered_interval_dnase_0_3;pred_reg_gene_centered_interval_cage_1_4;pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_8
# 48    parent_48  chr6  7393781  7394549  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_30   2.826324          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_30
# 49    parent_49  chr6  7401077  7401589  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_26   2.885993          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_26
# 50    parent_50  chr6  7403893  7405685   pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_9   3.820803          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_9
# 51    parent_51  chr6  7405941  7407349  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_10   3.741245          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_10
# 52    parent_52  chr6  7407989  7408501  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_24   3.005330          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_24
# 53    parent_53  chr6  7410933  7411829  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_20   3.343453          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_20
# 54    parent_54  chr6  7411957  7412597  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_22   3.104778          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_22
# 55    parent_55  chr6  7413877  7416181  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_14   3.681576          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_14
# 56    parent_56  chr6  7431669  7432181   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_9   2.426530          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_9
# 57    parent_57  chr6  7431925  7432437   pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_19   0.200388          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_19
# 58    parent_58  chr6  7434997  7436661    pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_6   5.875942          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_6
# 59    parent_59  chr6  7440885  7441397  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_16   2.051506          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_16
# 60    parent_60  chr6  7441141  7442677   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_26   3.666263          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_26
# 61    parent_61  chr6  7444597  7445749  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_18   1.901497          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_18
# 62    parent_62  chr6  7467765  7469173   pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_12   0.950549          3                                                                                                                                                                                                                                                                                                                                                                                     pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_12;pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_23;pred_reg_gene_centered_interval_dnase_0_14
# 63    parent_63  chr6  7483893  7484533   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_34   2.445992          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_34
# 64    parent_64  chr6  7491317  7493493    pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_1   8.184563          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_1
# 65    parent_65  chr6  7496309  7496821  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_14   2.096509          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_14
# 66    parent_66  chr6  7525749  7526645   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_8   2.546538          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_8
# 67    parent_67  chr6  7526773  7528309   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_3   3.026569          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_3
# 68    parent_68  chr6  7529205  7530613  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_15   2.096509          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_15
# 69    parent_69  chr6  7530997  7533429   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_4   2.966565          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_4
# 70    parent_70  chr6  7535221  7537141   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_5   2.876559          1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_5
# 71    parent_71  chr6  7537269  7546357   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_2   6.086764         10  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_2;pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_25;pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_23;pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_22;pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_8;pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_6;pred_reg_gene_centered_interval_dnase_0_10;pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_15;pred_reg_gene_centered_interval_cage_1_0;pred_reg_gene_centered_interval_cage_1_13
# ...
# 98    parent_54      iv_147  chr6  7411957  7412597  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_22   3.104778       True
# 99    parent_55      iv_139  chr6  7413877  7416181  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_14   3.681576       True
# 100   parent_56      iv_204  chr6  7431669  7432181   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_9   2.426530       True
# 101   parent_57       iv_57  chr6  7431925  7432437   pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_19   0.200388       True
# 102   parent_58      iv_165  chr6  7434997  7436661    pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_6   5.875942       True
# 103   parent_59      iv_211  chr6  7440885  7441397  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_16   2.051506       True
# 104   parent_60      iv_185  chr6  7441141  7442677   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_26   3.666263       True
# 105   parent_61      iv_213  chr6  7444597  7445749  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_18   1.901497       True
# 106   parent_62       iv_50  chr6  7467765  7469173   pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_12   0.950549       True
# 107   parent_62      iv_121  chr6  7468405  7468917   pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_23   1.415638      False
# 108   parent_62       iv_14  chr6  7468405  7468917                  pred_reg_gene_centered_interval_dnase_0_14   2.761057      False
# 109   parent_63      iv_193  chr6  7483893  7484533   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_34   2.445992       True
# 110   parent_64      iv_160  chr6  7491317  7493493    pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_1   8.184563       True
# 111   parent_65      iv_209  chr6  7496309  7496821  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_14   2.096509       True
# 112   parent_66      iv_203  chr6  7525749  7526645   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_8   2.546538       True
# 113   parent_67      iv_198  chr6  7526773  7528309   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_3   3.026569       True
# 114   parent_68      iv_210  chr6  7529205  7530613  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_15   2.096509       True
# 115   parent_69      iv_199  chr6  7530997  7533429   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_4   2.966565       True
# 116   parent_70      iv_200  chr6  7535221  7537141   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_5   2.876559       True
# 117   parent_71      iv_197  chr6  7537269  7546357   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_2   6.086764       True
# 118   parent_71      iv_123  chr6  7537397  7537909   pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_25   1.258714      False
# 119   parent_71       iv_61  chr6  7537397  7537909   pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_23   0.059856      False
# 120   parent_71       iv_60  chr6  7538165  7538933   pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_22   0.115277      False
# 121   parent_71       iv_46  chr6  7540341  7546229    pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_8   8.028586      False
# 122   parent_71      iv_104  chr6  7540981  7544821    pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_6   7.651658      False
# 123   parent_71       iv_10  chr6  7541237  7543413                  pred_reg_gene_centered_interval_dnase_0_10   5.775698      False
# 124   parent_71       iv_77  chr6  7541237  7543285   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_15   3.583950      False
# 125   parent_71       iv_23  chr6  7541237  7542133                    pred_reg_gene_centered_interval_cage_1_0  81.853874      False
# 126   parent_71       iv_36  chr6  7543029  7543541                   pred_reg_gene_centered_interval_cage_1_13   0.064325      False
# 127   parent_72      iv_202  chr6  7546485  7548789   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_7   2.576540       True
# 128   parent_73      iv_216  chr6  7551349  7551861  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_21   1.751487       True
# 129   parent_74       iv_16  chr6  7561205  7561717                  pred_reg_gene_centered_interval_dnase_0_16   1.075977       True
# 130   parent_75       iv_26  chr6  7579253  7581685                    pred_reg_gene_centered_interval_cage_1_3   3.828946       True
# 131   parent_76       iv_29  chr6  7582581  7586549                    pred_reg_gene_centered_interval_cage_1_6   1.548711       True
# 132   parent_77       iv_40  chr6  7589493  7592309    pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_2  13.602343       True
# 133   parent_77      iv_106  chr6  7589749  7590901    pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_8   6.205229      False
# 134   parent_77        iv_1  chr6  7590005  7590773                   pred_reg_gene_centered_interval_dnase_0_1  31.119389      False
# 135   parent_77       iv_73  chr6  7590773  7592181   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_11   3.767795      False
# 136   parent_78      iv_152  chr6  7595509  7596277  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_27   2.885993       True
# 137   parent_79      iv_142  chr6  7601525  7602293  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_17   3.462791       True
# 138   parent_80      iv_127  chr6  7605365  7607797   pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_2   4.616387       True
# 139   parent_81       iv_33  chr6  7608821  7611765                   pred_reg_gene_centered_interval_cage_1_10   0.118700       True
# 140   parent_82      iv_167  chr6  7639285  7640053    pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_8   5.546139       True
# 141   parent_83      iv_164  chr6  7662453  7664629    pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_5   6.733430       True
# 142   parent_84      iv_189  chr6  7668725  7669237   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_30   2.907717       True
# 143   parent_85      iv_201  chr6  7672309  7674485   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_6   2.756551       True
# 144   parent_85       iv_53  chr6  7672565  7673589   pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_15   0.507182      False
# 145   parent_86      iv_214  chr6  7682421  7683061  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_19   1.886496       True
# 146   parent_87      iv_215  chr6  7684853  7685493  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_20   1.856494       True
# 147   parent_88      iv_205  chr6  7691637  7692533  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_10   2.216517       True
# 148   parent_89       iv_59  chr6  7697909  7698677   pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_21   0.152884       True
# 149   parent_90      iv_194  chr6  7709557  7710069   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_35   2.445992       True
# 150   parent_91      iv_173  chr6  7710197  7711477   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_14   4.952494       True
# 151   parent_92      iv_161  chr6  7714677  7717237    pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_2   7.656878       True
# 152   parent_93      iv_196  chr6  7723253  7726965   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_1   6.266776       True
# 153   parent_94       iv_47  chr6  7725429  7731445    pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_9   7.553550       True
# 154   parent_93       iv_63  chr6  7725557  7726837    pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_1   5.348866      False
# 155   parent_93        iv_5  chr6  7725813  7726965                   pred_reg_gene_centered_interval_dnase_0_5  12.579798      False
# 156   parent_94       iv_25  chr6  7725941  7727605                    pred_reg_gene_centered_interval_cage_1_2   6.099062      False
# 157   parent_95      iv_195  chr6  7727093  7735285   pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_0   6.506791       True
# 158   parent_94       iv_17  chr6  7727093  7727989                  pred_reg_gene_centered_interval_dnase_0_17   1.047865      False
# 159   parent_94       iv_66  chr6  7727221  7727733    pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_4   4.539946      False
# 160   parent_94       iv_78  chr6  7727861  7728757   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_16   3.510412      False
# 161   parent_96      iv_208  chr6  7738229  7738997  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_13   2.111510       True
# 162   parent_97      iv_206  chr6  7739637  7740405  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_11   2.216517       True
# 163   parent_98      iv_207  chr6  7740533  7741941  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_12   2.216517       True
# 164   parent_99      iv_212  chr6  7742325  7742837  pred_reg_gene_centered_interval_chip_histone_2_H3K27me3_17   2.036505       True
# 165  parent_100      iv_178  chr6  7754101  7757045   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_19   4.523750       True
# 166  parent_101      iv_181  chr6  7765237  7766645   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_22   4.424809       True
# 167  parent_102      iv_170  chr6  7841909  7842805   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_11   5.315278       True
# 168  parent_103      iv_175  chr6  7848053  7849333   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_16   4.688652       True
# 169  parent_104      iv_182  chr6  7850101  7852661   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_23   4.160967       True
# 170  parent_105      iv_169  chr6  7872885  7874549   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_10   5.414218       True
# 171  parent_106      iv_174  chr6  7875061  7877365   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_15   4.853553       True
# 172  parent_107       iv_37  chr6  7880181  7883253                   pred_reg_gene_centered_interval_cage_1_14   0.056636       True
# 173  parent_108      iv_131  chr6  7881717  7885685   pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_6   3.979920       True
# 174  parent_109      iv_154  chr6  7885813  7886581  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_29   2.866103       True
# 175  parent_110      iv_128  chr6  7887093  7889653   pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_3   4.337933       True
# 176  parent_111      iv_150  chr6  7890805  7891829  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_25   2.965551       True
# 177  parent_112      iv_158  chr6  7892469  7892981  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_33   2.567759       True
# 178  parent_113      iv_140  chr6  7893109  7894005  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_15   3.641797       True
# 179  parent_114      iv_141  chr6  7894645  7896053  pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_16   3.621907       True
# 180  parent_115      iv_132  chr6  7898229  7899509   pred_reg_gene_centered_interval_chip_histone_2_H3K36me3_7   3.979920       True
# 181  parent_116       iv_95  chr6  7904501  7905269   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_33   2.775030       True
# 182  parent_116       iv_20  chr6  7904629  7905141                  pred_reg_gene_centered_interval_dnase_0_20   0.806478      False
# 183  parent_117       iv_43  chr6  7908341  7911669    pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_5   9.295349       True
# 184  parent_117      iv_107  chr6  7909237  7910773    pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_9   6.177938      False
# 185  parent_117       iv_83  chr6  7909237  7910133   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_21   3.326566      False
# 186  parent_117        iv_8  chr6  7909365  7911413                   pred_reg_gene_centered_interval_dnase_0_8   9.850882      False
# 187  parent_117       iv_34  chr6  7910389  7911029                   pred_reg_gene_centered_interval_cage_1_11   0.091763      False
# 188  parent_117      iv_105  chr6  7910901  7911541    pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_7   6.314393      False
# 189  parent_117       iv_71  chr6  7911029  7911541    pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_9   3.951641      False
# 190  parent_118      iv_159  chr6  7924085  7927157    pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_0  11.944315       True
# 191  parent_119      iv_177  chr6  7929973  7930741   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_18   4.655672       True
# 192  parent_120      iv_179  chr6  7930997  7931893   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_20   4.490770       True
# 193  parent_121      iv_190  chr6  7932405  7932917   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_31   2.907717       True
# 194  parent_122      iv_186  chr6  7934325  7935349   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_27   3.501362       True
# 195  parent_123      iv_192  chr6  7942773  7943413   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_33   2.676854       True
# 196  parent_124      iv_184  chr6  7948021  7949557   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_25   3.864145       True
# 197  parent_125      iv_188  chr6  7957493  7958005   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_29   3.039638       True
# 198  parent_126      iv_187  chr6  7964917  7965557   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_28   3.435401       True
# 199  parent_127      iv_163  chr6  7969525  7971061    pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_4   7.261115       True
# 200  parent_128       iv_92  chr6  7974517  7975157   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_30   2.995645       True
# 201  parent_129      iv_116  chr6  7974645  7976181   pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_18   2.084270       True
# 202  parent_129       iv_54  chr6  7974901  7976053   pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_16   0.463637      False
# 203  parent_129        iv_6  chr6  7974901  7975413                   pred_reg_gene_centered_interval_dnase_0_6  12.344575      False
# 204  parent_129       iv_69  chr6  7975541  7976181    pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_7   4.245793      False
# 205  parent_130      iv_176  chr6  7979637  7981301   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_17   4.688652       True
# 206  parent_131      iv_183  chr6  7983349  7985141   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_24   4.095007       True
# 207  parent_132      iv_191  chr6  7986165  7986805   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_32   2.808776       True
# 208  parent_133      iv_168  chr6  7993333  7993973    pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_9   5.480179       True
# 209  parent_134       iv_86  chr6  8028405  8029045   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_24   3.216259       True
# 210  parent_135       iv_96  chr6  8029173  8029685   pred_reg_gene_centered_interval_chip_histone_2_H3K4me1_34   2.701492       True
# 211  parent_136      iv_171  chr6  8031221  8032629   pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_12   5.117396       True
# 212  parent_137      iv_162  chr6  8032885  8033525    pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_3   7.393035       True
# 213  parent_138      iv_166  chr6  8033781  8035189    pred_reg_gene_centered_interval_chip_histone_2_H3K9me3_7   5.678061       True
# 214  parent_139       iv_41  chr6  8063093  8065141    pred_reg_gene_centered_interval_chip_histone_2_H3K4me3_3  13.095637       True
# 215  parent_139      iv_102  chr6  8063605  8065013    pred_reg_gene_centered_interval_chip_histone_2_H3K27ac_4  12.291147      False
# 216  parent_139        iv_2  chr6  8063861  8064629                   pred_reg_gene_centered_interval_dnase_0_2  29.407402      False

# %% [markdown]
# ### Save collapsed parents and members
#
# When `save` is True, write the collapsed parent and members tables as CSVs plus a BED of parent intervals (`…_collapsed.bed`) for overlay or IGV.

# %%
if save:
    pred_regions_collapsed_df.to_csv(
        f"outputs/predicted_reg_regions_{gene_context}_indivtracks_LV_128res_collapsed.csv",
        index=False,
    )
    pred_regions_members_df.to_csv(
        f"outputs/predicted_reg_regions_{gene_context}_indivtracks_LV_128res_members.csv",
        index=False,
    )
    # BED of collapsed parent intervals (chrom/start/end/name/score) for overlay / IGV
    pred_regions_collapsed_df[["chrom", "start", "end", "name", "score"]].to_csv(
        f"outputs/predicted_reg_regions_{gene_context}_indivtracks_LV_128res_collapsed.bed",
        index=False,
        sep="\t",
    )
    print("saved collapsed + members CSVs and collapsed BED!")
# Out:
# saved collapsed + members CSVs and collapsed BED!

# %% [markdown]
# ## cCRE-like region calling and export
#
# Run `classify_ccre_like_regions` on the LV prediction `output` using notebook `tss_df` (from `gene_annotation.extract_tss`), export a class-annotated BED/CSV, and print class counts. Per-modality peaks above are unchanged; this is the combinatorial ENCODE-style path.

# %%
save_ccre = True

ccre_result = classify_ccre_like_regions(
    output,
    tss_df=gene_tss_df,
    tissue_curie=LV_UB,
    resolution_bp=128,
    threshold_method="percentile",
    threshold_value=95,
    min_width_bp=500,
    merge_gap_bp=1,
)

ccre_regions_df = ccre_intervals_to_bed_df(
    ccre_result["intervals"],
    name_prefix=f"pred_ccre_{gene_context}",
)

print(
    f"Called {len(ccre_regions_df)} cCRE-like regions "
    f"(TSS annotations used: {ccre_result['tss_count']})"
)
print(ccre_regions_df["cCRE_class"].value_counts(dropna=False))

if save_ccre:
    ccre_bed_path = (
        f"outputs/predicted_ccre_like_regions_{gene_context}_LV_128res.bed"
    )
    ccre_csv_path = (
        f"outputs/predicted_ccre_like_regions_{gene_context}_LV_128res.csv"
    )
    # BED-like TSV for overlay loaders; full CSV keeps flag/score columns
    ccre_regions_df.to_csv(ccre_bed_path, index=False, sep="\t")
    ccre_regions_df.to_csv(ccre_csv_path, index=False)
    print(f"saved {ccre_bed_path}")
    print(f"saved {ccre_csv_path}")

ccre_regions_df
# Out:
# [False False False ... False False False]
# [False False False ... False False False]
# [False False False ... False False False]
# [False False False ... False False False]
# [False False False ... False False False]
# Called 25 cCRE-like regions (TSS annotations used: 18)
# cCRE_class
# Distal enhancer      17
# CA-TF                 4
# Proximal enhancer     1
# Unclassified          1
# TF                    1
# CA-CTCF               1
# Name: count, dtype: int64
# saved outputs/predicted_ccre_like_regions_gene_centered_interval_LV_128res.bed
# saved outputs/predicted_ccre_like_regions_gene_centered_interval_LV_128res.csv
#    chrom    start      end                                               name  \
# 0   chr6  7312373  7313525  pred_ccre_gene_centered_interval_0_Distal enha...
# 1   chr6  7590005  7590773  pred_ccre_gene_centered_interval_1_Distal enha...
# 2   chr6  8063861  8064629  pred_ccre_gene_centered_interval_2_Distal enha...
# 3   chr6  7389301  7390325  pred_ccre_gene_centered_interval_3_Distal enha...
# 4   chr6  7140597  7141621  pred_ccre_gene_centered_interval_4_Distal enha...
# 5   chr6  7725813  7726965  pred_ccre_gene_centered_interval_5_Distal enha...
# 6   chr6  7974901  7975413  pred_ccre_gene_centered_interval_6_Distal enha...
# 7   chr6  7260789  7262325  pred_ccre_gene_centered_interval_7_Distal enha...
# 8   chr6  7909365  7911413  pred_ccre_gene_centered_interval_8_Distal enha...
# 9   chr6  7106677  7109877  pred_ccre_gene_centered_interval_9_Distal enha...
# 10  chr6  7541237  7543413  pred_ccre_gene_centered_interval_10_Proximal e...
# 11  chr6  7050869  7052917  pred_ccre_gene_centered_interval_11_Distal enh...
# 12  chr6  7169269  7169781  pred_ccre_gene_centered_interval_12_Distal enh...
# 13  chr6  7146229  7146741  pred_ccre_gene_centered_interval_13_Distal enh...
# 14  chr6  7468405  7468917  pred_ccre_gene_centered_interval_14_Distal enh...
# 15  chr6  7142261  7142773  pred_ccre_gene_centered_interval_15_Distal enh...
# 16  chr6  7143285  7143797   pred_ccre_gene_centered_interval_16_Unclassified
# 17  chr6  7561205  7561717  pred_ccre_gene_centered_interval_17_Distal enh...
# 18  chr6  7727093  7727989  pred_ccre_gene_centered_interval_18_Distal enh...
# 19  chr6  7248501  7249013          pred_ccre_gene_centered_interval_19_CA-TF
# 20  chr6  7119349  7119861             pred_ccre_gene_centered_interval_20_TF
# 21  chr6  7246325  7247093        pred_ccre_gene_centered_interval_21_CA-CTCF
# 22  chr6  7904629  7905141          pred_ccre_gene_centered_interval_22_CA-TF
# 23  chr6  7229429  7230581          pred_ccre_gene_centered_interval_23_CA-TF
# 24  chr6  7231093  7231989          pred_ccre_gene_centered_interval_24_CA-TF
#
#         score         cCRE_class   d_tss  high_CA  high_H3K4me3  high_H3K27ac  \
# 0   37.397278    Distal enhancer  228376     True          True          True
# 1   31.119389    Distal enhancer   19911     True          True          True
# 2   29.407402    Distal enhancer  493767     True          True          True
# 3   22.895754    Distal enhancer  151512     True          True          True
# 4   15.740975    Distal enhancer  400216     True          True          True
# 5   12.579798    Distal enhancer  155911     True          True          True
# 6   12.344575    Distal enhancer  404679     True          True          True
# 7   10.639538    Distal enhancer  279768     True          True          True
# 8    9.850882    Distal enhancer  339911     True          True          True
# 9    7.133498    Distal enhancer  433048     True          True          True
# 10   5.775698  Proximal enhancer     302     True          True          True
# 11   5.146157    Distal enhancer  489432     True          True          True
# 12   3.816099    Distal enhancer  371800     True         False          True
# 13   3.661287    Distal enhancer  394840     True          True          True
# 14   2.761057    Distal enhancer   72664     True          True          True
# 15   1.308828    Distal enhancer  398808     True         False          True
# 16   1.127077       Unclassified  397784    False         False          True
# 17   1.075977    Distal enhancer    2176     True         False          True
# 18   1.047865    Distal enhancer  157063     True          True          True
# 19   1.007950              CA-TF  292568     True         False         False
# 20   0.881791                 TF  421720    False         False         False
# 21   0.825633            CA-CTCF  294616     True         False         False
# 22   0.806478              CA-TF  334407     True         False         False
# 23   0.759804              CA-TF  311320     True         False         False
# 24   0.583845              CA-TF  309784     True         False         False
#
#     high_CTCF  high_TF     max_CA  max_H3K4me3  max_H3K27ac  max_CTCF  \
# 0        True     True  37.397278    14.615753    16.002739  1.136430
# 1        True     True  31.119389    13.602343     6.205229  1.633926
# 2        True     True  29.407402    13.095637    12.291147  3.496348
# 3        True     True  22.895754    11.702198    13.055298  4.542366
# 4        True     True  15.740975     8.345277    15.784410  1.570145
# 5        True     True  12.579798     7.553550     1.333765  1.468094
# 6        True     True  12.344575     0.329044     1.784068  0.441211
# 7        True     True  10.639538     6.856831     3.421535  1.289506
# 8        True     True   9.850882     9.295349     6.314393  3.674936
# 9        True     True   7.133498    14.045710    14.583601  4.312752
# 10       True     True   5.775698     8.028586     7.651658  0.371051
# 11       True     True   5.146157     8.471953     8.197480  1.493607
# 12      False     True   3.816099    -0.045047     2.207081  0.058521
# 13       True     True   3.661287     0.554686     5.713989  0.536883
# 14       True     True   2.761057     0.950549     1.415638  0.176517
# 15      False     True   1.308828     0.016311     2.329890 -0.069042
# 16       True     True   0.388946    -0.037130     1.565740  2.258986
# 17      False     True   1.075977    -0.001502     1.135904 -0.040340
# 18       True     True   1.047865     5.558399     1.054031  1.455338
# 19      False     True   1.007950    -0.148467     0.092019 -0.062664
# 20      False     True   0.092111    -0.092551     0.211418 -0.075420
# 21       True     True   0.825633    -0.163806    -0.162129  1.289506
# 22      False     True   0.806478    -0.034161     0.583259  0.112736
# 23      False     True   0.759804    -0.154405    -0.117781 -0.113689
# 24      False     True   0.583845    -0.146487     0.054494  0.048954
#
#        max_TF
# 0   17.393448
# 1   19.355740
# 2   14.914762
# 3   18.529510
# 4   16.360662
# 5   15.431155
# 6    3.270107
# 7   11.558210
# 8   17.186890
# 9   12.539356
# 10  18.322954
# 11   5.103301
# 12   1.294905
# 13   2.288961
# 14   2.082403
# 15   1.178716
# 16   1.127077
# 17   1.165807
# 18   2.004945
# 19   0.701053
# 20   0.881791
# 21   0.765602
# 22   0.778512
# 23   0.726873
# 24   0.675233

# %% [markdown]
# # Visualize predictions and overlays
#
# Load either cCRE-like or modality-collapsed predicted regions, assign colors, and overlay them on multi-track LV prediction plots.

# %% [markdown]
# ## Load predicted-region BED and assign colors
#
# Set `OVERLAY_SOURCE` to `"ccre"` (ENCODE-style classes) or `"modality"` (per-track collapsed peaks). Load the matching BED, then assign overlay colors from `CCRE_COLORS` or modality/histone maps.

# %%
# "ccre" = combinatorial ENCODE-style classes; "modality" = per-track collapsed peaks
OVERLAY_SOURCE = "ccre"

if OVERLAY_SOURCE == "ccre":
    bed_path = f"outputs/predicted_ccre_like_regions_{gene_context}_LV_128res.bed"
    bed_intervals, bed_df = load_bed_intervals(bed_path)
    # Prefer explicit cCRE_class column when present; else parse from name suffix
    if "cCRE_class" in bed_df.columns:
        bed_df["category"] = bed_df["cCRE_class"]
    else:
        bed_df["category"] = (
            bed_df["name"].astype(str).str.rsplit("_", n=1).str[-1]
        )
    bed_df["color"] = bed_df["category"].map(
        lambda c: CCRE_COLORS.get(c, "gray")
    )
else:
    bed_path = (
        f"outputs/predicted_reg_regions_{gene_context}_"
        "indivtracks_LV_128res_collapsed.bed"
    )
    bed_intervals, bed_df = load_bed_intervals(bed_path)
    bed_df["category"] = bed_df["name"].map(category_from_name)
    bed_df["color"] = bed_df["category"].map(color_from_category)

colors = bed_df["color"].tolist()
bed_df
# Out:
# loaded 25 intervals from bed file
#    chrom    start      end                                               name  \
# 0   chr6  7312373  7313525  pred_ccre_gene_centered_interval_0_Distal enha...
# 1   chr6  7590005  7590773  pred_ccre_gene_centered_interval_1_Distal enha...
# 2   chr6  8063861  8064629  pred_ccre_gene_centered_interval_2_Distal enha...
# 3   chr6  7389301  7390325  pred_ccre_gene_centered_interval_3_Distal enha...
# 4   chr6  7140597  7141621  pred_ccre_gene_centered_interval_4_Distal enha...
# 5   chr6  7725813  7726965  pred_ccre_gene_centered_interval_5_Distal enha...
# 6   chr6  7974901  7975413  pred_ccre_gene_centered_interval_6_Distal enha...
# 7   chr6  7260789  7262325  pred_ccre_gene_centered_interval_7_Distal enha...
# 8   chr6  7909365  7911413  pred_ccre_gene_centered_interval_8_Distal enha...
# 9   chr6  7106677  7109877  pred_ccre_gene_centered_interval_9_Distal enha...
# 10  chr6  7541237  7543413  pred_ccre_gene_centered_interval_10_Proximal e...
# 11  chr6  7050869  7052917  pred_ccre_gene_centered_interval_11_Distal enh...
# 12  chr6  7169269  7169781  pred_ccre_gene_centered_interval_12_Distal enh...
# 13  chr6  7146229  7146741  pred_ccre_gene_centered_interval_13_Distal enh...
# 14  chr6  7468405  7468917  pred_ccre_gene_centered_interval_14_Distal enh...
# 15  chr6  7142261  7142773  pred_ccre_gene_centered_interval_15_Distal enh...
# 16  chr6  7143285  7143797   pred_ccre_gene_centered_interval_16_Unclassified
# 17  chr6  7561205  7561717  pred_ccre_gene_centered_interval_17_Distal enh...
# 18  chr6  7727093  7727989  pred_ccre_gene_centered_interval_18_Distal enh...
# 19  chr6  7248501  7249013          pred_ccre_gene_centered_interval_19_CA-TF
# 20  chr6  7119349  7119861             pred_ccre_gene_centered_interval_20_TF
# 21  chr6  7246325  7247093        pred_ccre_gene_centered_interval_21_CA-CTCF
# 22  chr6  7904629  7905141          pred_ccre_gene_centered_interval_22_CA-TF
# 23  chr6  7229429  7230581          pred_ccre_gene_centered_interval_23_CA-TF
# 24  chr6  7231093  7231989          pred_ccre_gene_centered_interval_24_CA-TF
#
#         score         cCRE_class   d_tss  high_CA  high_H3K4me3  high_H3K27ac  \
# 0   37.397278    Distal enhancer  228376     True          True          True
# 1   31.119389    Distal enhancer   19911     True          True          True
# 2   29.407402    Distal enhancer  493767     True          True          True
# 3   22.895754    Distal enhancer  151512     True          True          True
# 4   15.740975    Distal enhancer  400216     True          True          True
# 5   12.579798    Distal enhancer  155911     True          True          True
# 6   12.344575    Distal enhancer  404679     True          True          True
# 7   10.639538    Distal enhancer  279768     True          True          True
# 8    9.850882    Distal enhancer  339911     True          True          True
# 9    7.133498    Distal enhancer  433048     True          True          True
# 10   5.775698  Proximal enhancer     302     True          True          True
# 11   5.146157    Distal enhancer  489432     True          True          True
# 12   3.816099    Distal enhancer  371800     True         False          True
# 13   3.661287    Distal enhancer  394840     True          True          True
# 14   2.761057    Distal enhancer   72664     True          True          True
# 15   1.308828    Distal enhancer  398808     True         False          True
# 16   1.127077       Unclassified  397784    False         False          True
# 17   1.075977    Distal enhancer    2176     True         False          True
# 18   1.047865    Distal enhancer  157063     True          True          True
# 19   1.007950              CA-TF  292568     True         False         False
# 20   0.881791                 TF  421720    False         False         False
# 21   0.825633            CA-CTCF  294616     True         False         False
# 22   0.806478              CA-TF  334407     True         False         False
# 23   0.759804              CA-TF  311320     True         False         False
# 24   0.583845              CA-TF  309784     True         False         False
#
#     high_CTCF  high_TF     max_CA  max_H3K4me3  max_H3K27ac  max_CTCF  \
# 0        True     True  37.397278    14.615753    16.002739  1.136430
# 1        True     True  31.119389    13.602343     6.205229  1.633926
# 2        True     True  29.407402    13.095637    12.291147  3.496348
# 3        True     True  22.895754    11.702198    13.055298  4.542366
# 4        True     True  15.740975     8.345277    15.784410  1.570145
# 5        True     True  12.579798     7.553550     1.333765  1.468094
# 6        True     True  12.344575     0.329044     1.784068  0.441211
# 7        True     True  10.639538     6.856831     3.421535  1.289506
# 8        True     True   9.850882     9.295349     6.314393  3.674936
# 9        True     True   7.133498    14.045710    14.583601  4.312752
# 10       True     True   5.775698     8.028586     7.651658  0.371051
# 11       True     True   5.146157     8.471953     8.197480  1.493607
# 12      False     True   3.816099    -0.045047     2.207081  0.058521
# 13       True     True   3.661287     0.554686     5.713989  0.536883
# 14       True     True   2.761057     0.950549     1.415638  0.176517
# 15      False     True   1.308828     0.016311     2.329890 -0.069042
# 16       True     True   0.388946    -0.037130     1.565740  2.258986
# 17      False     True   1.075977    -0.001502     1.135904 -0.040340
# 18       True     True   1.047865     5.558399     1.054031  1.455338
# 19      False     True   1.007950    -0.148467     0.092019 -0.062664
# 20      False     True   0.092111    -0.092551     0.211418 -0.075420
# 21       True     True   0.825633    -0.163806    -0.162129  1.289506
# 22      False     True   0.806478    -0.034161     0.583259  0.112736
# 23      False     True   0.759804    -0.154405    -0.117781 -0.113689
# 24      False     True   0.583845    -0.146487     0.054494  0.048954
#
#        max_TF           category    color
# 0   17.393448    Distal enhancer  #FFCD00
# 1   19.355740    Distal enhancer  #FFCD00
# 2   14.914762    Distal enhancer  #FFCD00
# 3   18.529510    Distal enhancer  #FFCD00
# 4   16.360662    Distal enhancer  #FFCD00
# 5   15.431155    Distal enhancer  #FFCD00
# 6    3.270107    Distal enhancer  #FFCD00
# 7   11.558210    Distal enhancer  #FFCD00
# 8   17.186890    Distal enhancer  #FFCD00
# 9   12.539356    Distal enhancer  #FFCD00
# 10  18.322954  Proximal enhancer  #FFA700
# 11   5.103301    Distal enhancer  #FFCD00
# 12   1.294905    Distal enhancer  #FFCD00
# 13   2.288961    Distal enhancer  #FFCD00
# 14   2.082403    Distal enhancer  #FFCD00
# 15   1.178716    Distal enhancer  #FFCD00
# 16   1.127077       Unclassified     gray
# 17   1.165807    Distal enhancer  #FFCD00
# 18   2.004945    Distal enhancer  #FFCD00
# 19   0.701053              CA-TF  #D876EC
# 20   0.881791                 TF  #D876EC
# 21   0.765602            CA-CTCF  #00B0F0
# 22   0.778512              CA-TF  #D876EC
# 23   0.726873              CA-TF  #D876EC
# 24   0.675233              CA-TF  #D876EC

# %% [markdown]
# ## Multi-track plot with BED overlay
#
# Plot plus-strand RNA-seq and CAGE along with ChIP-histone, ChIP-TF, and DNase tracks over `POST_INTERVAL`. Overlay the colored `bed_intervals`, add a modality/histone legend, and optionally save the figure under `figs/` when `save` is True.

# %%
# plot_interval = POST_INTERVAL
plot_interval = CENTRAL_INTERVAL #genome.Interval('chr1', POST_INTERVAL.start, POST_INTERVAL.start + 50000)
# plot_interval = genome.Interval('chr1', PRE_INTERVAL.end - 50000, PRE_INTERVAL.end)
# plot_interval = genome.Interval('chr1', GENE_START - 10000, GENE_END + 10000)
save = True
add_annos = True

# Build plot.
plot = plot_components.plot(
    [
        plot_components.TranscriptAnnotation(longest_transcripts),
        plot_components.Tracks(
            tdata=output.rna_seq.filter_to_positive_strand(),
            ylabel_template='RNA_SEQ: {biosample_name} ({strand})\n{name}',
        ),
        plot_components.Tracks(
            tdata=output.cage.filter_to_positive_strand(),
            ylabel_template='CAGE: {biosample_name} ({strand})\n{name}',
        ),
        # Chip histone.
        plot_components.Tracks(
            tdata=output.chip_histone,
            ylabel_template='Chip Histone: {biosample_name} ({strand})\n{name}',
        ),
        # Chip tf.
        plot_components.Tracks(
            tdata=output.chip_tf,
            ylabel_template='Chip TF: {biosample_name} ({strand})\n{name}',
        ),
        #  # ATAC
        # plot_components.Tracks(
        #     tdata=output.atac,
        #     ylabel_template='ATAC: {biosample_name} ({strand})\n{name}',
        # ),
        # dnase
        plot_components.Tracks(
            tdata=output.dnase,
            ylabel_template='DNASE: {biosample_name} ({strand})\n{name}',
        ),
        #  # splice sites
        # plot_components.Tracks(
        #     tdata=output.splice_sites,
        #     ylabel_template='Splice Sites: ({strand})\n{name}',
        # ),
       
    ],
    # add annotations from a bed file (imported and parsed above)
    annotations=[
        plot_components.IntervalAnnotation(
            bed_intervals, #ccre_intervals,
            colors=colors, #ccre_colors
            alpha=0.2,
            # use_default_labels=False,   # True if you want cCRE IDs as labels
            # labels=bed_df["name"].tolist(),
        ),
    ],
     
    interval=plot_interval,
    fig_width=25,
    title='Predictions for LV heart tissue',
)

# legend_handles = [
#     mpatches.Patch(color=color, label=key) 
#     for key, color in CCRE_COLORS.items()
# ]
# plot.legend(handles=legend_handles, loc="center left", title="Categories",
#           bbox_to_anchor=(1, 0, 0.5, 1))


if OVERLAY_SOURCE == "ccre":
    # Legend follows ENCODE class color map; only classes present in this window
    label_order = list(CCRE_COLORS)
    used = [c for c in label_order if c in set(bed_df["category"])]
    handles = [
        mpatches.Patch(color=CCRE_COLORS.get(c, "gray"), label=c) for c in used
    ]
    legend_title = "cCRE class"
    fig_suffix = "ccre_like"
else:
    label_order = list(MODALITY_COLORS) + HISTONE_MARKS
    used = [c for c in label_order if c in set(bed_df["category"])]
    handles = [
        mpatches.Patch(color=color_from_category(c), label=c) for c in used
    ]
    legend_title = "Modality"
    fig_suffix = "ccres_collapsed"

plot.legend(
    handles=handles,
    title=legend_title,
    loc="center left",
    bbox_to_anchor=(1, 0, 0.5, 1),
)

if save:
    plot.savefig(
        f"figs/{TARGET_GENE}_predictions_LV_1MB_{gene_context}_{fig_suffix}.png",
        dpi=300,
        bbox_inches="tight",
    )
    plot.savefig(
        f"figs/{TARGET_GENE}_predictions_LV_1MB_{gene_context}_{fig_suffix}.pdf",
        dpi=300,
        bbox_inches="tight",
    )

# %% [markdown]
# # Reference notes
#
# Background on ENCODE cCRE classes. These definitions drive `assign_ccre_class` / `classify_ccre_like_regions` above. High/low in this notebook use within-window percentiles on AlphaGenome tracks (not ENCODE genome-wide max-Z).
#
# ## cCRE class decision tree
#
# Priority order used by `assign_ccre_class` (first matching rule wins):

# %% [markdown]
# ```mermaid
# flowchart TD
#   peak[Candidate peak] --> caQ{"high_CA?"}
#
#   caQ -->|yes| k4Q{"high_H3K4me3?"}
#   caQ -->|no| tfOnlyQ{"high_TF and low marks?"}
#
#   k4Q -->|yes| d200a{"d_tss <= 200?"}
#   k4Q -->|no| k27Q{"high_H3K27ac?"}
#
#   d200a -->|yes| promoter[Promoter]
#   d200a -->|no| k27k4{"high_H3K27ac?"}
#
#   k27k4 -->|yes| d2000a{"d_tss <= 2000?"}
#   k27k4 -->|no| caK4[CA-H3K4me3]
#
#   k27Q -->|yes| d2000b{"d_tss <= 2000?"}
#   k27Q -->|no| ctcfQ{"high_CTCF?"}
#
#   d2000a -->|yes| proxEnh1[Proximal enhancer]
#   d2000a -->|no| distEnh1[Distal enhancer]
#
#   d2000b -->|yes| proxEnh2[Proximal enhancer]
#   d2000b -->|no| distEnh2[Distal enhancer]
#
#   ctcfQ -->|yes| caCtcf[CA-CTCF]
#   ctcfQ -->|no| tfQ{"high_TF?"}
#
#   tfQ -->|yes| caTf[CA-TF]
#   tfQ -->|no| caAlone[CA]
#
#   tfOnlyQ -->|yes| tfAlone[TF]
#   tfOnlyQ -->|no| unclass[Unclassified]
# ```

# %% [markdown]
# **Quick criteria**
#
# | Class | high_CA | high_H3K4me3 | high_H3K27ac | high_CTCF | high_TF | d_tss |
# |---|---|---|---|---|---|---|
# | Promoter | yes | yes | — | — | — | ≤ 200 |
# | Proximal enhancer | yes | — | yes | — | — | ≤ 2000 |
# | Distal enhancer | yes | — | yes | — | — | > 2000 |
# | CA-H3K4me3 | yes | yes | no | — | — | > 200 |
# | CA-CTCF | yes | no | no | yes | — | — |
# | CA-TF | yes | no | no | no | yes | — |
# | CA | yes | no | no | no | — | — |
# | TF | no | no | no | no | yes | — |
#
#
# ## ENCODE cCRE class definitions (notebook mapping)
#
# - Promoter-like signatures (promoter) must fall within 200 bp of a TSS and have high chromatin accessibility and H3K4me3 signals.
# - TSS-proximal enhancer-like signatures (proximal enhancer) have high chromatin accessibility and *H3K27ac* signals and are within 2 kb of an annotated TSS. If they are within 200 bp of a TSS, they must also have low H3K4me3 signal.
# - TSS-distal enhancer-like signatures (distal enhancer) have high chromatin accessibility and *H3K27ac* signals and are farther than 2 kb from an annotated TSS.
# - Chromatin accessibility + H3K4me3 (CA-H3K4me3) have high chromatin accessibility and H3K4me3 signals but low *H3K27ac* signals and do not fall within 200 bp of a TSS.
# - Chromatin accessibility + CTCF (CA-CTCF) have high chromatin accessibility and CTCF signals but low H3K4me3 and *H3K27ac* signals.
# - Chromatin accessibility + transcription factor (CA-TF) have high chromatin accessibility, low H3K4me3, *H3K27ac*, and CTCF signals, and are bound by a transcription factor.
# - Chromatin accessibility (CA) have high chromatin accessibility and low H3K4me3, *H3K27ac*, and CTCF signals.
# - Transcription factor (TF) have low chromatin accessibility, low H3K4me3, *H3K27ac*, and CTCF signals and are bound by a transcription factor.
#
# https://github.com/weng-lab/ENCODE-cCREs/tree/master/Version-4/cCRE-Pipeline
#
# ## Groups based on function-associated signatures
#
# A cCRE requires support from two distinct experimental assays: accessible DNA as measured by a high DNase signal and at least one high ChIP–seq signal (H3K4me3, H3K27ac, or CTCF) in the pertinent ChIP–seq dataset. The pertinent ChIP–seq dataset allows the cCREs to be classified into general groups. Specifically, three major annotation groups are defined using the following categorization schema for both human and mouse (Box 1 Fig. 1):
#
# ### 1. Active and poised enhancer-like elements
#
# cCREs annotated with enhancer-like signatures (**cCRE-ELS**) have high DNase and H3K27ac signals and, if they fall within 2,000 bp of an annotated TSS, they must also have low relative H3K4me3 signal. ELSs are further partitioned into two subclasses on the basis of broader proximity to the TSS:
#
# - **1a. Proximal enhancer-like elements (pELS):** fall within 2 kb of a TSS.
# - **1b. Distal enhancer-like elements (dELS):** fall more than 2 kb from the nearest TSS.
#
# ### 2. Active and poised promoter-like elements
#
# cCREs annotated with promoter-like signatures (**cCRE-PLS**) possess high DNase signals and high H3K4me3 signals. They are partitioned into two subclasses on the basis of their proximity to a TSS:
#
# - **2a. Canonical promoter-like elements (cCRE-PLS):** fall within 200 bp (centre-to-centre) of an annotated GENCODE TSS that has high DNase and H3K4me3 signals.
# - **2b. Other high-H3K4me3 elements:** have high DNase with high H3K4me3 but low H3K27ac signals and do not fall within 200 bp of an annotated TSS. These elements may denote poised canonical promoters, non-canonical promoter-like elements, or elements with other functions that lie within the high-H3K4me3 signal region around a canonical promoter.
#
# ### 3. CTCF-only elements
#
# CTCF-only cCREs have high DNase and CTCF signals but low signals for H3K4me3 and H3K27ac. These isolated CTCF elements are candidates for insulators and looping functions in which CTCF participates. Other regulatory elements (ELS and PLS) can also be bound by CTCF, where this protein may also participate in those roles.
#
# From paper DOI: 10.1038/s41586-020-2493-4
